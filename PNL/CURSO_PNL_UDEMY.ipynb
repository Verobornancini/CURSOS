# %% [markdown]
# # PROCESAMIENTO DEL LENGUAJE NATURAL

# %% [markdown]
# ![1.jpg](attachment:34413268-997c-431d-b83a-33b0be7ad87a.jpg)

# %% [markdown]
# # LIBRERÍAS:
# * Numpy -> Enfocada al cálculo numérico, vectoriza los valores de un array para permitir operar con ellos.
# * Pandas ->
# * Matplotlib ->

# %%
import numpy as np

alturas= np.array([1.5, 1.7, 1.6])

pesos= np.array([60, 74, 78])

IMC= pesos/alturas

IMC.round(1)
# Out:
# array([40. , 43.5, 48.8])
