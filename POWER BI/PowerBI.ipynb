# %% [markdown]
# # Power BI

# %% [markdown]
# ## Bloque 1: GET DATA
# * Carga de datos:
#  * * Subir archivos de texto o exel
#  * * Integrar bases de datos como SQLServer
#  * * Integrar servicios en linea como Facebook y Google Analytics

# %% [markdown]
# ##  Bloque 2: DATA PREPARATION
# * Limpieza de datos y organización de manera estructurada:
#  * * Gestor de datos integrado en PoweBI: Great Manager

# %% [markdown]
# ##  Bloque 3: DATA MODELLING
# * Relacionar datos entre las distintas fuentes
# * Realizar cálculos para obtener resultados relevantes

# %% [markdown]
# ##  Bloque 4: DATA VISUALLIZATION
# * Generación de gráficos, tablas, y visualizaciones para analizar datos

# %% [markdown]
# ##  Bloque 5: DATA REPORTING
# * Asignamos un mejor formato, colores y vistas a nuestro reporte

# %% [markdown]
# ![consignas_PROYECTO_1.jpg](attachment:12619bbb-8c38-485e-8adc-166e5b8991b6.jpg)

# %% [markdown]
# **1.1 Obtención de datos:** *Get data* -> excel ->*load*
#
# **1.2 Prepapración de datos:** Abrimos el query manager desde *Edit queries* ó *Transform data*
# * **Eliminar columnas:** Eliminaremos una columna llamada Ventas global, con le boton *Remove columns*
# * **Unificar columnas:** Haremos que todas las columnas de ventas por paises sean unificadas en una sola columa. Para ello seleccionamos todas las columnas de ventas y aplicamos la transformación:
#  *Transform* -> *Unpivot columns*
# Me genera 2 columnas una llamada Attribute (la renombramos como Region) y la otra llamada value (la renombramos como Venta (millones)).
# * **Renombrar valores de una columna:** Selecciono el nombre de la columna y con click derecho elijo la opcion *Replace Value*, completamos el valor a buscar, por el valor a reemplazar.
# * **Cambiar tipo de dato:** Cambiaremos el tipo de dato de la columna año a tipo texto, para que no me sume los valores de los años. Para ello hago click en la pestaña de archivo, en la opción *Close & apply*.

# %% [markdown]
# **1.3 Modelado de datos:** En el panel de la izquiera, la opción *Data*, nos permite ver el dataset que ya habíamos preparado. Podemos hacer diferentes consultas en los datos, según nuestras necesidades.
# * **Ordenar los datos:** En la columna ventas millones hacemos Click derecho y elegimos la opción **Sort Descending**, para ver los videojuegos que más ventas han tenido.
# * **Ajustes de datos:** Seleccionando la columna ventas millones, tocamos arriba la opción **Column tools**. Utilizando todas las opciones qe se despliegan podemos elegir las que se ajusten al tipo de modelado de datos que queremos realizar (cantidad de decimales, tipo de numero o moneda, operaciones simples como suma, media, conteo, etc.)

# %% [markdown]
# **1.4 Visualización de datos:** El objetivo de este proyecto es clasificar las ventas por medio de las diferentes categorías.
# * **Tabla:** En la hoja de *Report* seleccionamos en el panel de la derecha el ícono *Table*, y elegimos Año, Nombre y Venta.
# * **Graficos:** Se pueden agragar gáficos de torta, de barras y de líneas, según las conveniencias del reporte.
# * **Cards:** Las encontramos en el ícono que dice 123, en este caso seleccionaremos la variable Ventas.
# * **Slice:** Son filtros que nos permiten interactuar con las otras visualizaciones. Elegimos la variable año.

# %% [markdown]
# **BONUS**
# * **Buscador:** Para agregar la opción de buqueda en los filtros (slice): Hacer click con el filtro y tocar los tres puntitos que aparecen en la parte superior. Cuando se despliegan las opciones, debemos elegir *Search*.
# * **Filtros:**
#  * **Data View:** Me permite ver la tabla y aplicar filtros, pero sin modificar el acceso a la info del dashboard
#  * **Query manager:** Modifica la información que voy a tener disponible en el dashboard
# * **Grillas:** Para ver grillas punteadas en los gráficos puedo usar las opciones en la pestaña *View* -> *Show Grid Lines*
# * **Copiar formato:** Puedo modificar los ejes, textos, colores de cada visualización, tambien el formato de los tooltips. Una vez definido el formato de la visualización, puedo copiarlo en otras usando el *Format Painter*. Para ello, selecciono el pincel y pego el formato, vuelvo a seleccionar y pego... y asi...
#
# **1.5 reporte de datos**

# %% [markdown]
# ![PROYECTO_1.jpg](attachment:e301b6e2-264d-4697-9831-cd6543490e96.jpg)

# %% [markdown]
# ![consignas_PROYECTO_2.jpg](attachment:0969499c-dc01-416f-9aab-743bb921083c.jpg)

# %% [markdown]
# **1.1 Obtención de datos:** *Get data* -> csv ->*load*
#
# **1.2 Prepapración de datos:**
# * **Separador de miles (coma):** Primero creo una tabla en el dashboard, y luego agrego la separación de miles a los datos de la tabla. Para ellos selecciono la columna de Population, y voy al apartado *Modeling* -> *coma:,*.
# * **Ordenar los datos:** Toco los tres puntos sobre la tabla y selecciono la opcion *Sort By:* population, y luego **sort desending**.

# %% [markdown]
# **1.3 Modelado de datos:**
# * **Asignar nombre de columnas:** Abrimos la tabla Countries. Esta nueva tabla no tiene los nombres de las columnas asignados. Los nombres de las columnas deberian ser la información que está en la primer fila. Para ello antes de poner *Load*, cliclearemos en la opción *Transform Data*. Con *Shift* seleccionamos los nombres de las columnas, nos vamos a *HOME* -> *Use first row as header* -> *Close & apply*.
# * **Unión entre tablas:** Para indicar a que continente pertenecen los números poblacionales, uniremos dos tablas que cuentan con la misma referencia (país). Vamos al apartado de *MODEL* (en el lado izquierdo de la pantalla). Si coloco el mouse sobre la linea que une las dos tablas, me indica cuales son los campos que generan la unión. Si quiero generar manualmente esta relación, me puedo parar sobre la linea y poner *delete*. Luego me paro sobre un campo de una tabla y lo arrastro hacia el campo con el que lo quiero relacionar de la otra tabla, y vemos que la linea de unión se vuelve a generar.Vuelvo al dashboard y agrego en la tabla la columna que necesitaba (Continenete). De este modo queda unificada la información de las dos tablas. Anexo: Para saber que continente tiene la mayor cantidad de población, remuevo de la tabla el campo País.
# * **Visualización de matriz:** Una vez que solo tengo las columnas continentes y población. cambio el tipo de visualización de tabla a matriz. Activo el campo countries(paises) de la segunda tabla(countries) y arrastro el campo countries por debajo del campo continent en el apartado *row*. Voy al rodillo de *Format*, y en el apartado *Row headers* activo la opción *+/- icons*. Ahora obtengo una tabla con menues desplegables que al seleccionar un continente despliega la lista de paises. Anexo: Para pasar los nombres de los paises a español, abrimos la tercer tabla llamada paises y repetimos el proceso de unificación de tablas.

# %% [markdown]
# **1.4 Visualización de datos:**
# * **Categorización:** Asignaremos diferentes categorías de acuerdo a la cantidad de población.Desde el editor (Transform data) voy a la tabla de population, y agrego una tercer columna desde el menu *Add column* y selecciono *conditional column*. Seteo en nuevo nombre de la columna y la condición de la misma (if  population, is less than or equal, value 1000000, then 0-1M), (Else if  population, is less than or equal, value 10000000, then 1-10M), (Else if  population, is less than or equal, value 100000000, then 10-100M), (Else 100M +. Volvemos a *Home* -> *Close & apply*. Una vez seteadas las categorías, volvemos al dashboard y agregamos el campo (Cantidad de población) como primer elemento en el apartado de *ROWS*.Obsservaremos como se genera una nueva categoría que agrupa a los paises por cantidad de población. Anexo: Podemos quitar a continentes de *Rows*, pero luego debemos agragarlo nuevamente para continuar con el ejercicio.
# * **Visualización por categorías**: En la ventana del dashboard, crearemos filtros de categorias usando *Slicers*: Uno seleccionando cantidad de población, y otro seleccionando continentes.
# * **Visualización por jerarquía:** Seleciconamos la opción de *Treamap*, primero elegimos el campo país y luego población.
# * **Mapas:** Estas visualizaciones se conenctan con *Bing maps* para su funcionamiento, por lo tanto es importante contar con una conexión a internet estable. Comenzamos seleccionando el ícono *Maps*, es importante saber que los datos utilizados para usar mapas, deben ser reconocidos como datos de ubicación. Para ellos vamos a modelarlos desde el aprtado *Modeling*, luego elegimos el campo al que le queremos agragar la categoría, en este caso elegimos continente, vamos a las opciones del encabezado y seleccionamos *Data category* -> *Continent* (aparecrá un mundito de enlace al lado de la categoría). Repetimos el proceso para el campo país. Finalmente seleccionamos el mapa y los datos modelados de continente y paises. Anexo: Agregamos el campo population si queremos que los círculos tengan un tamaño proporcional a la cantidad de población.
# * **Filled Map:** Es otrs opción para hacer mapas. En el apartado *Legend* indicamos lo que queremos representar y nos pintará las localizaciones de provincias o estados completos en vez de hacer una buruja. La escala de color es según la información de cada localización.
# * **Ordenar categorias promediando sus valores:** Abrimos dos nuevas tablas y las renombramos como "Mortalidad Infantil" y "Esperanza de Vida". Chequeamos las relaciones entre tablas. Duplicamos el dashboard y trabajaremos en la nueva pestaña. Agregamos en la tabla las columnas de Mortalidad y Esperanza. Veremos que los valores totales para cada continente se expresan como una sumatoria de todos los paises, y deberían ser el promedio de los valores de estos. Para esto haremos un cambio de operación a mostrar. Para ello vamos al aprtado de valores y tocamos en la variable Mortalidad, en la lista que se despliega elegimos la opcion *Avg (Average)*. Repetimos para la variable Esperanza de vida.
#
# **1.5 Reporte de datos (Hoja 1)**

# %% [markdown]
# ![PROYECTO_2.jpg](attachment:ec8f15f6-26f4-4923-a28e-b2f3df3fffa3.jpg)

# %% [markdown]
# **1.5 Reporte de datos (Hoja 2)**
# * Podemos agregar mas columnas condicionales por ejemplo para categorizar la mortalidad infantil y la esperanza de vida.
# * Agregamos luego los Slicers(filtros) correspondiente a cada categoría.
# * Modificamos el mapa dejando seteadas las opciones de: Locaion=País; Size=Mortalidad Infantil.
# * Para cambiar el color de las burbujas: *Format*-> *data colors* -> *default color* ->*f(x)* Aqui seteamos las condiciones de la escala de color.
# * **Correlación entre datos:** Podemos ver la correlación entre la Esperanza de Vida y Mortalidad infantil utilizando los **Scatter charts** (diagramas de dispersión). Llenamos los cmapos como: Details=Pais; XAxis=Mortalidad Infantil; YAxis= Esperanza de Vida.
# * Se puede aplicar formato condicional a las columnas de la tabla, apra colorear cada valor con la escala del mapa.

# %% [markdown]
# ![consignas_PROYECTO_2_bonus.jpg](attachment:aa758387-d3d1-408e-ad0b-4b437b633df0.jpg)

# %% [markdown]
# **Bonus**
# * En modo enfoque (*Focus map*) que se encuentra en la esquina superior derecha de cada visualización, podemos hacer una ampliación de la misma.
# * En la misma esquina si selecciono los 3 puntos, puedo pedirle que me muestre los datos con los que se realizó esa visualización.
# * Puedo también exportar esos datos como un archivo .csv
# * **Filtros:** Por ejemplo; si quisieramos que todas las visualizaciones nos mostrataran solamente 2 continentes, debo seleccionar el slicer de continentes, luego debemos ir a la pestaña despleglabe de *Filters* y allí seleccionar solos los 2 continentes que queremos mostrar. Asi podemos aplicar filtros para cada una de las visualizaciones. Tmbien podemos aplicar los filtros de nivel de página (*Filters on this page*) para aplicar el mismo filtro a todas las visualizaciones del dashboard.
# * **Modos de Jerarquía:** Las visualizacion que tienen 2 o mas jerarquias (continentes, paises, etc) tienen la opcion de habilitar en la esquina superior derecha el ícono de Dill Up. Esto permite que seleccionemos la jerarquia que queremos ver.
# * De ser necesario podemos mostrar promedios en vez de sumatorias en los graficos de dispersión, cuando agrupo los datos por jerarquias. de esto modo veo el promedio de un dato por continente y no la sumatoria de todos los paises del mismo.

# %% [markdown]
# ![consignas_PROYECTO_3.jpg](attachment:18679b65-a930-4ec2-8d79-c1a95e0ed297.jpg)

# %% [markdown]
# **1.1 Obtención de datos:** *Get data* -> excel ->*load*
#
# **1.2 Prepapración de datos:** Abrimos el query manager desde *Edit queries* ó *Transform data*
# * Hacemos los pasos ya explicados en este apartado que sean necesarios para estas tablas.
#
# **1.3 Modelado de datos:**
# * **Tabla:** agregamos una tabla al reporte con las columnas de; nombre, posicion, estado y sexo.
# * **Funciones DAX - Conteo de empleados:** Primero creamos una medida o *measure* . Para ellos hacemos click derecho en el nombre de la tabla empleados en el menú derecho y seleccionamos *new measure*. Esto me abre una barra en la parte superior de la ventana donde puedo escribir una fórmula. En este caso haremos una para contar la cantidad de empleados
# (Total empleados= COUNT('Tabla+Empleados'[Id empleado])).
# * **Tarjeta:** Agregamos una *card* y le introducimos el campo que acabamos de crear (Total empleados).
# * **Grafico de dona** Seteamos; Legend=sexo; Values=total de empleados.
# * **Gáfico de barras:** Seteamos; Axis=departamento; Values=total de empleados.
# * **Mapa:** Primero seleccionamos el campo estado y marcamos que pertenece a un dato de localizacion. *Columns Tools* ->*Data Category* -> *State or province* (Aparecerá un mundito al lado del cmapo estado). Agnamos el campo Total de empleados en *Size*.
# * **Funciones DAX - Sueldo promedio:** En la tabla de sueldo. Hcemos click derecho en el nombre de la tabla sueldos en el menú derecho y seleccionamos *new measure*. Esto me abre una barra en la parte superior de la ventana donde puedo escribir una fórmula
# (Sueldo Promedio=AVERAGE('Tabla+Sueldo'[Sueldo]).
# * **Funciones DAX - Evaluación promedio:** En la tabla de evaluación primero debo chequear eque el campo tenga el tipo correcto de datos, y sino hacer la modificación necesaria, de ser necesario se puede agregar una nueva columna para redondear los valores de las calificaciones. Como hicimos anteriormente hcemos click derecho en el nombre de la tabla evaluación en el menú derecho y seleccionamos *new measure*, y escribimos la fórmula
# (Sueldo Promedio=AVERAGE('Tabla+Sueldo'[Sueldo]).
# * **Funciones DAX - Edad:** Primero vamos a la vista de datos y seleecionamos la tabla de empleados y agregamos una nueva columna *new column* (vamos a conventir la info de fecha de nacimienro en edad), Utilizamos la siguiente fórmula para calcular la edad.
# Edad = INT(YEARFRAC('Tabla Empleados'[Nacimiento],TODAY())) -> los parametros son la fecha de inicio que es nacimiento y la fecha final que es today.
# * **Tooltips**: Agregamos al tooltip del gráfico de dona la informacion de las nuevas columnas promedio que creamos.

# %% [markdown]
# **Crear categorías por grupos de DAX**
# * Vamos a la ventana de datos -> vamos a la tabla de empleados y seleccionamos -> *table tools* -> *new column* y escribimos con funciones DAX las condiciones de la nueva columna:
# Grupo Edad =
# IF('Tabla Empleados'[Edad] <= 30 , "20-30" ,
# IF('Tabla Empleados'[Edad] <= 40, "30-40" ,
# IF('Tabla Empleados'[Edad] <= 50 , "40-50" ,
# IF('Tabla Empleados'[Edad] <= 60 , "50-60" ,
# IF('Tabla Empleados'[Edad] <= 70 , "60-70" ,
# "Mas 70"
# )))))
# * En un grafico de barras representaremos los grupos etarios. en Axis=Grupos de edad

# %% [markdown]
# * Vamos a la ventana de datos -> vamos a la tabla de sueldos y seleccionamos -> *table tools* -> *new column* y escribimos con funciones DAX las condiciones de la nueva columna:
# Grupo Sueldo =
# IF('Tabla Sueldo'[Sueldo] <= 40000 , "0-40K" ,
# IF('Tabla Sueldo'[Sueldo] <= 60000 , "40-60K" ,
# IF('Tabla Sueldo'[Sueldo] <= 80000 , "60-80K" ,
# IF('Tabla Sueldo'[Sueldo] <= 100000 , "80-100K",
# "Mas 100K"
# ))))

# %% [markdown]
# * Vamos a la ventana de datos -> vamos a la tabla de evaluación y seleccionamos -> *table tools* -> *new column* y escribimos con funciones DAX las condiciones de la nueva columna:
# Grupo Evaluacion =
# IF('Tabla Evaluacion'[Evaluacion] <= 6 , "0-6" ,
# IF('Tabla Evaluacion'[Evaluacion] <= 7 , "6-7" ,
# IF('Tabla Evaluacion'[Evaluacion] <= 8 , "7-8" ,
# IF('Tabla Evaluacion'[Evaluacion] <= 9 , "8-9" ,
# "9-10"
# ))))

# %% [markdown]
# * **BOOKMARKS:** *Insert* ->*Buttons* ->*Bookmark*, luego editaremos el texto, luego en *Outline* seleccionamos *On hover* para que al pasar el mouse encima cambie de color. En *fill* seteamos los colores que debería tener en on hover y en default.
# * Creo 3 bookmarks con distinto nombre y copio la página del dashboard 3 veces. Asigno a cada página, el mismo nombre de los booksmarks de cada página. A cada página copiada le debo agregar el bookmark correspondiente en la lista de la derecha (luego las edito para mostrar diferentes cosas en cada una).
# * **Acciones:** En el menú de *View* selecciono *Bookmarks* (abre un panel nuevo al lado de visualizaciones).
# * Selecciono en el panel de *Bookmarks* la opciín *Add* y le pongo al bookmark el nombre que tiene la página y el boton asociado. Luego voy a la otra página y repito la acción, agregando un Bookmark por cada página.
# * Ahora le agregamos las acciones a los botones: En el panel *Visualizations*, seteo en ON la opción de *Acction*; Actions=Bookmark; Bookmark=(nombre de esa pagina y el botón asociado). Hago lo mismo en todas las páginas.
# * En el modo desktop debemos presionar la tecla CTRL y hacer click n el boton para que funcione el redireccionamiento del bookmark. En la version On-line no es necesario.
# * Para diferenciar las páginas. Seteamos en default un color diferente para el bookmark correspondiente de esa página.

# %% [markdown]
# **Compartir Reportes con POWERBI SERVICE**
# * En la esquina derecha superior tocar en SIGN IN y entrar a tu cuenta (crear una en caso de no tener).
# * En el POWER BI DESKTOP: FILE -> PUBLISH -> PUBLISH TO POWER BI
# * En el POWER BI WEB: FILE -> PUBLISH TO WEB

# %% [markdown]
# **Ask a Question**
# * Es una herramienta para consultar en inglés, y nos devuelve la gráfica que responda esa pregunta.
# **Filtro por TOP N**
# * Creamos dos gráficos (Ejemplo: evaluaciones de empleados, evaluaciones de jefes), y luego creamos un filtro (ejemplo: departameto)
# * luego me posiciono en el gráfico: TOOLTIPS -> FILTER -> VISUAL LEVEL FILTER -> FILTER TYPE -> TOP N (y agregamos cuantas respuestas entraran entre las tops, 3 mejores, 5 mejores, etc.) -> BY VALUE (indico el atributo por el que quiero filtrar.)
# **Drillthrough**
# * Filtro de una página en otra. Primero lo activo. Luego voy al grafico de interes y selecciono un valor, hago clock con el botón derecho y se despliega una lista de donde selecciono *Drillthrough* -> y hacia que pagina la quiero aplicar. Eso me cambia de página y me muestra la info filtrada.

# %% [markdown]
# ![proyecto_4.JPG](attachment:63b38aa1-9e75-46c2-b8f3-2364a2a5c9c9.JPG)

# %% [markdown]
# ![proyecto_4.JPG](attachment:f0953385-4928-40c3-96b7-0d77fe93e72e.JPG)

# %% [markdown]
# **Actualizar datos si cambiamos el nombre del archivo original**
# *TRANSFORM DATA* -> *DATA SOURCE SETTINGS* -> Cambiamos la direccion de la fuente, ponemos buscar y buscamos el archivo con el nombre modificado

# %% [markdown]
# * **Unir tablas (APPEND):** Nos posicionamos en TRANSFORM DATA en la tabla TablaIngresos -> CUSTOM COLUM -> nombre:Tipo; formula="Ingresos". Hacemos lo mismo con la tabla gastos. Luego vamos a HOME -> COMBINE -> APPEND QUERIES. Las columnas de la tabla que unimos aparecen abajo de las que tenemos.
# * **Transformar fechas:** En la tabla de *Metas* la fecha solo tiene dos campos, para que sea considerada fecha debemos agregarle el día. TRANSFORM -> FORMAT -> ADD PREFIX -> 1/
# * **Unir columnas:** Unimos las columnas de ingresos (Remuneración + Ventas) TRANFORMATION -> UNPIVOT COLUMNS. Le ponemos nuevos nombres a las columnas (Categoria y Cantidad). Luego agregamos otra columna -> ADD -> CUSTOM COLUMN -> nombre:Tipo; formula="Metas".
# * Ahora editamos igual la tabla de presupuesto y luego la unimos con la tabla metas.

# %% [markdown]
# **Modelado de datos**
# * **Tabla Finanzas:** creamos nuevas medidas:
# * * **Total Finanzas =** SUM(Finanzas[Cantidad])
# * * **Ingresos =** CALCULATE([Total Finanzas],Finanzas[Tipo]="Ingresos")
# * * **Gastos =** CALCULATE([Total Finanzas],Finanzas[Tipo]="Gastos")
#
# * **Grafico de lineas:** Obtengo el mismo gráfico haciendo:
# * * Axis=fecha (seteo con el click derecho que solo me muetsre fecha, sin todas las opciones de dias y esa info); Values=Total Finanzas;Legend=Tipo.
# * * Axis=fecha (seteo con el click derecho que solo me muetsre fecha, sin todas las opciones de dias y esa info); Values=Ingresos, Gastos
# * **Tabla por tipos:** Creo una nueva tabla y pongo como values: Fecha, Ingresos, Gastos. Posicionados en la tabla, vamos al menu DATA -> COLUMN TOOLS
# * * **Total Expectativas =** SUM(Expectativas[Cantidad])
# * * **Meta =** CALCULATE([Total Expectativas],Expectativas[Tipo]="Metas")
# * * **Presupuesto =** CALCULATE([Total Expectativas],Expectativas[Tipo]="Presupuesto")
# * **Grafico de lineas:** Obtengo el mismo gráfico haciendo:
# * * Axis=fecha (seteo con el click derecho que solo me muetsre fecha, sin todas las opciones de dias y esa info); Values=Total Finanzas;Legend=Tipo.
# * * Axis=fecha (seteo con el click derecho que solo me muetsre fecha, sin todas las opciones de dias y esa info); Values=Ingresos, Gastos
#
# * **Relacionar tablas con fechas=** desde MODELING creo una nueva tabla con NEW TABLE y pego el código del archivo DAX CALENDARIO. Luego voy a RELACIONES y armo las relaciones entre las tablas. Dsp voy a cada grafico y cambio el apartado fecha que tenian, por el nuevo campo DATE de la tabla DAX CALENDARIO.
# * Otra forma de trabajar con calendarios es importar la carpeta con calendarios de excel. podemos unificar si tenemos 2 ó más años. Luego de mportarlas vamos al menu TRANSFORM DATA (Query editor) -> ADD COLUMN ->DATE -> elijo las opciones que quiero agregar.
#
# * **Utilidad =** [Ingresos]-[Gastos]
# * **UT.Esperada=** [Meta]-[Presupuesto]
#
# **Visualizacion**
# * **TARJETA DE MULTIPLES RENGLONES:**
#
#
# * Grafico Gague: primero creamos una neva medida de porcentaje:
# * * Cuota Ingresos=[Ingresos]/[Meta]. Luego ponemos este campo en una visualizacion de Gague
# * * Cuota Gastos=[Gastos]-[Ingresos]
# * * Cuota Utilidad=[Utilidad]-[UT.Esperada]
# * Tabla Finanzas - New Measure:
# * * Saldo = CALCULATE( [Utilidad], FILTER( ALL(Finanzas) , Finanzas[Fecha] <= MAX(Finanzas[Fecha])))
# * Tabla Expectativas - New Measure
# * * Saldo Esperado = CALCULATE( [Ut. Esperada], FILTER( ALL(Expectativas), Expectativas[Fecha] <= MAX(Expectativas[Fecha])))

# %% [markdown]
# **Sincronizar slicers**
# * VIEW -> SINC SLICER

# %% [markdown]
# ![proyecto4.jpg](attachment:3142cd2b-4676-48dd-93ef-24a8b934487a.jpg)

# %% [markdown]
# ![proyecto_6.jpg](attachment:a4381391-f158-4c59-9df8-8f439ee2c297.jpg)

# %% [markdown]
# ### **Buenas prácticas para modelado de datos**
# * Un modelo contará con tablas conectadas por medio de relaciones
# * El modelado de datos consiste en: Cargar las tablas, relacionarlas, transformar los datos con expresiones DAX
# * Cada entidad de negocio debe tener su propia tabla, ejemplo: Si analizamos escuelas podriamos tener tablas como; Calificaciones, Asistencias, Maestros, Alumnos, Materias, Exámenes.
# * Las entidades de negocio se diferencian en dos tipos:
#  * * FACT(HECHOS):Campos que se pueden medir. Tienen muchos registros y pocas variables.
#  * * DIM (DIMENSIONES): Se utilizan para segmentar las tablas FACT, responden a las preguntas de Quien, Donde, Como y Cuanto sucedió el evento medido en las tablas FACT.
# * Las relaciones entre tablas se hacen mediante KEY que son claves que permiten la unión. Al momento de crear expresiones DAX usaremos el campo que esté presente en las tablas DIM. Es una buena práctica, ocultar el mismo campo presente en la tabla FACT. Si tenemos tablas DIM relacionadas debemos ocultar una de las KEY, nos quedamos con aquella que corresponda a la info de la primera tabla.

# %% [markdown]
# ![Captura de pantalla 2020-09-20 223929.jpg](attachment:02734807-c13c-4ee2-b284-06dd4b1ada3b.jpg)

# %% [markdown]
# ## Existen difetentes tipos de modelados
# ### 1) Modelo en Estrella

# %% [markdown]
# ![modelo_en_estrella.jpg](attachment:40028565-2062-4526-934f-99d89c6a1e90.jpg)

# %% [markdown]
# ### Modelo en Arbol
# * Puede usarse con una sola tabla FACT. Pero es útil cuando tenemos varias tablas FACT ya que nos deja espacio libre para poner hacer las uniones con ambas.

# %% [markdown]
# ![modelo_en _arbol.jpg](attachment:679ceeb8-f51c-4cdb-9cf9-7595efe0e41b.jpg)

# %% [markdown]
# ![modelo_en _arbol_con_muchas_fact.jpg](attachment:c393368e-a63e-479b-b38c-a8fe17704260.jpg)

# %% [markdown]
# ### Buenas prácticas con expresiones DAX
# * Es muy saludable crear una nueva tabla llamada DAX Medidas, donde podamos ir almacenando todas las medidas que creemos

# %% [markdown]
# ![atajos dax.jpg](attachment:0e6c5705-a0da-41df-b81c-fba803a1897a.jpg)

# %% [markdown]
# **Concatenar Colunas de texto:**
# * UbicacionCompleta = DimGeography[RegionCountryName] &", "& DimGeography[ContinentName]
# **Funcion RELATED**
# * Creo una nueva columna en la tabla DimStore:
#     * Ubicacion Fisica = RELATED(DimGeography[UbicacionCompleta])
#     * Ubicacion Fisica = IF(DimStores[StoreType]="Store", DimStores[Ciudad]&","& RELATED(DimGeography[UbicacionCompleta]), BLANK())
# * Me trae el dato de la ubicación completa que s eencuentra en la otra tabla (DimGeography)
# *COUNTBLANCK =Para contar si hay registros en blanco

# %% [markdown]
# **CALENDARIO**
# * Voy al Query editor o Transform data. Selecciono la opción *New Source* -> *Blanq Query* -> *Advanced editor*, elimino lo que aprece de texto y pego el código de la tabla calendario (ver mas abajo). Aplicar los cambios y colocar los datos que me pide a continuación, debo colocar las fechas de los datos que tengo en mi base de datos ->*Invoque function* -> *Close & apply*
# * **Tabla medida:** Hecha con funciones DAX. HOME -> NEW TABLE. Una vez creada la tabla selecciono NEW MEASURE y creo una variable que sea la suma de mi valor. luego elimino la columna 1 que se crea por default. Cierro y vuelvo a abrir la pestaña de FIELDS (aparece un ícono de calculadora en la nueva tabla).
# * Creo una nueva columna de suma por categoría con un filtro de cobro por operaciones:
#
#
# **FUNCIONES DAX**
# * **CALCULATE:** Esta función permite realizar operaciones teniendo en cuenta filtros o condiciones, la función CALCULATE se usa para filtrar mediante un argumento que pasamos a la función. Esto es lo que se conoce como funciones anidadas. La función CALCULATE tiene al menos dos argumentos. El primero es la expresión que se evalúa; el segundo, un filtro, por ejemplo:
#     * Efectivo Inicial = CALCULATE(SUM('Flujo de Caja'[Value]), FILTER('Flujo de Caja', 'Flujo de Caja'[Meses]= "Dinero liquido al inicio (caja y bancos)"))
#     * Admite operaciones sobre alguna columna (SUM(columna1)).
#
# * ALL: Se utiliza como un filtro dentro de CALCULATE, se usa para incluir a todos los registros de una tabla, por ejemplo:
#     * All Total Ordenes = CALCULATE([Total Ordenes], ALL(FactSales))
#
# * **FILLTER:** Primero aplica el filtro que especifiquemos en la tabla,y luego hace el cálculo que definimos en el primer término antes de la coma. En el filtro, se coloca el nombre de la tabla y luego de una coma el campo con la expresion que quiero filtrar.
#     * Total Ordenes devueltas Multiples Filter = CALCULATE([Total Ordenes],FILTER(FactSales, FactSales[ReturnQuantity]>0))
#     * Fillter además nos permite usar como filtros a métricas previamente creadas por nosotros, que no podemos usarlas con calculate si no ponemos a filter en el filtro propiamente dicho.
#
# * **RELATED:** Permite tomar campos de otras tablas, por ejemplo:
#     * Precio unitario: RELATED(Dimproduct [UnitPrice]) -> Traigo a una nueva tabla la columna de unitprice y la renombro.
#
# * **SUMX:** Para hacer sumatorias de multiplicaciones de dos campos de una tabla o de distintas tablas. Por ejemplo:
#     * Total Ingresos mismatabla = SUMX(factsales, factsales[cantidad total] * factsales[precio unitario])
#     * Total Ingresos dostablas = SUMX(FactSales, FactSales[Cantidad Total] * RELATED(DimProduct[UnitPrice]))
#
# * **RANKX:** Para crer un ranking de medidas. Por ejemplo:
#         * Rank_ingresos_tiendas= RANKX(ALL(Dimstore), [Total ingresos])
#     * Si tenemos registros en blancos podemos filtrarlos para que no se aplique en ellos la formula de rank.
#         * Rank_ingresos_tiendas= IF(ISBLANK[Total ingresos]),BLNAK(),RANKX(ALL(Dimstore), [Total ingresos]))
#     * Si queremos invertir el orden del ranking
#         * Rank_ingresos_tiendas= RANKX(ALL(Dimstore), [Total costos],,ASC)
#     * Si queremos hacer un ranking según una categoría, por ejemplo: los primeros puestos por continente. Con ALLSELECTED la función se aplica según los filtros seleccionados en pantalla.
#         * Rank_ingresos_tiendas= RANKX(ALLSELECTED(Dimstore), [Total costos],,ASC)
#
# * **SWITCH:** Es una función similar al IF. Cuando sea verdadera cualquier condicion dsp del TRUE, muestra un resultado, en este caso una clasificacion de pequeña, mediana y grande.
#     * Categoria Tamaño Tienda = SWITCH( TRUE(),
#         DimStores[SellingAreaSize] <= 500, "Pequeña",
#         DimStores[SellingAreaSize] <= 800, "Mediana",
#         DimStores[SellingAreaSize] > 800, "Grande",
# "Otro")
#
# **ESTRELLAS**
# Star Unichar =
# VAR star = UNICHAR(9733)   #estrella llena
# VAR star0 = UNICHAR(9734)  # estrella vacia
# RETURN
# REPT(star, 4) & star0
#
#
# Rank Ingresos Tiendas Cat Unichar =
# VAR star = "⭐️"   #puede usarse un emoji entre comillas
# VAR star0 = UNICHAR(9734)   # puede usarse un codigo unichart
# RETURN
# IF(HASONEVALUE(DimStores[Tienda]),
# SWITCH( TRUE(),
# [Rank Ingresos Tiendas] <= 10 , REPT(star,5),
# [Rank Ingresos Tiendas] <= 25 , REPT(star,4) & REPT(star0,1),
# [Rank Ingresos Tiendas] <= 50 , REPT(star,3) & REPT(star0,2),
# [Rank Ingresos Tiendas] <= 100 , REPT(star,2) & REPT(star0,3),
# REPT(star,1) & REPT(star0,4)) , BLANK()
# )

# %% [markdown]
# **TIME INTELLIGENCE** = Funciones para trabajar con periodos de tiempo
# * DATESYTD: Se utiliza como filtro de la función CALCULATE. Se aplica sobre el campo de fecha de la tabla calendario. YTD =  YEAR TO DATE =Acumulado hasta la fecha.
#  * * YTD Ingresos = CALCULATE([Total Ingresos], DATESYTD(DimCalendar[DateKey]))
#
# * TOTALYTD: Si queremos usar una sola función en vez de usar CALCULATE y DATESYTD, puedo utilizar la fución TOTALYTD (ambas opciones dan el mismo resultado):
#  * * YTD Ingresos 2 = TOTALYTD([Total Ingresos], DimCalendar[DateKey])
#
# * TOTALMTD: Para acumular por meses, Cuando termina de acumular por los dias de un mes, vuelve a iniciar y acumula nuevamente desde ep rimer día del mes siguiente hasta el último:
#  * * MTD Ingresos = TOTALMTD([Total Ingresos], DimCalendar[DateKey])
#
# * **GRAFICAR EL ACUMULADO POR AÑO:** En un gráfico de área, como eje X pongo el ampo de fecha, como legend coloco el año y como valor, el YTD ingresos

# %% [markdown]
# ![acumulado por año.jpg](attachment:34bbc774-9cd8-4785-b130-d10b5f5a1b7c.jpg)

# %% [markdown]
# * SAMEPERIODLASTYEAR: Para calcular los acumulados del mismo periodo del año anterior:
#  * * Total Ingresos LY = CALCULATE([Total Ingresos], SAMEPERIODLASTYEAR(DimCalendar[DateKey]))
#
# **CALCULAR LA DIFERENCIA DE INGRESOS DEL AÑO SELECCIONADO RESPECTO DEL AÑO ANTERIOR**
# * Total Ingresos Variacion LY = [Total Ingresos] - [Total Ingresos LY]
# **COLOCAR ICONOS SOBRE VARIACIÓN POSITIVA O NEGATIVA**
# * FORMAT -> CONDITIONAL FORMATING -> CAMPO DONDE QUIERO EL ÍCONO (Total Ingresos Variacion LY)-> ICONS ->ADVANCED CONTROLS ->EDITAR REGLAS

# %% [markdown]
# ![ICONOS.jpg](attachment:ae091740-0197-4353-a609-6e26b29bca57.jpg)

# %% [markdown]
# AÑO_ADECUADO = IF(FACTURACION[empresa]="SIGLO 21" || FACTURACION[empresa]="CENCAP",FACTURACION[año],FACTURACION[periodo])* DATEADD: Para calcular los ingresos del mes anterior:
#  * * Total Ingresos LM = CALCULATE([Total Ingresos], DATEADD(DimCalendar[DateKey],-1,MONTH))

# %% [markdown]
# # Pronosticos
# #### Forecast y parámetros

# %% [markdown]
# * Elegir una visualización de curva
# * Poner el campo calendar de la tabla de calendario y una medida que querramos graficar en el tiempo (Total Utilidad)
# * Vamos al panel ANALYTICS -> podemos agragar una linea de tendencia o una línea de promedio
# * en la seccion FORECAST podemos agregar a la gráfica un pronóstico según lo que veamos en el grafico.... dias, meses, años

# %% [markdown]
# ## Tooltips
# * Puedo crear una pagina nueva y en formato le aplico la opción que sea tipo tooltip. ahi diseño el tooltip como quiero que se vea.
# * Luego voy a mi reporte y elijo una visualización a la cual le puedo editar el tooltip que trae por defecto y coloca el que acabo de crear.
# * Puede tener gráficos y el texto que deseemos.
